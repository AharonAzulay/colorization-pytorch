# %%
# !git clone https://github.com/AharonAzulay/colorization-pytorch.git
# !cd colorization-pytorch
# Out:
# Cloning into 'colorization-pytorch'...
# remote: Enumerating objects: 147, done.
# remote: Counting objects: 100% (147/147), done.
# remote: Compressing objects: 100% (125/125), done.
# remote: Total 1577 (delta 25), reused 134 (delta 20), pack-reused 1430
# Receiving objects: 100% (1577/1577), 27.31 MiB | 1.86 MiB/s, done.
# Resolving deltas: 100% (988/988), done.

# %%
# !python make_ilsvrc_dataset.py --in_path /isilon/Datasets/ImageNet/
# Out:
# Copying ILSVRC from...[/isilon/Datasets/ImageNet/]
# Making small training set in...[./dataset/ilsvrc2012/train_small]
# Making training set in...[./dataset/ilsvrc2012/train]
# Making validation set in...[./dataset/ilsvrc2012/val/imgs]
# cp: cannot stat '/data/big/dataset/ILSVRC2012/validation/ILSVRC2012_val_00000001.JPEG': No such file or directory
# cp: cannot stat '/data/big/dataset/ILSVRC2012/validation/ILSVRC2012_val_00000002.JPEG': No such file or directory
# cp: cannot stat '/data/big/dataset/ILSVRC2012/validation/ILSVRC2012_val_00000003.JPEG': No such file or directory
# cp: cannot stat '/data/big/dataset/ILSVRC2012/validation/ILSVRC2012_val_00000004.JPEG': No such file or directory
# cp: cannot stat '/data/big/dataset/ILSVRC2012/validation/ILSVRC2012_val_00000005.JPEG': No such file or directory
# cp: cannot stat '/data/big/dataset/ILSVRC2012/validation/ILSVRC2012_val_00000006.JPEG': No such file or directory
# ...

# %%
# !bash pretrained_models/download_siggraph_model.sh
# Out:
# WARNING: timestamping does nothing in combination with -O. See the manual
# for details.
#
# --2020-11-04 16:24:55--  http://colorization.eecs.berkeley.edu/siggraph/models/pytorch.pth
# Resolving colorization.eecs.berkeley.edu (colorization.eecs.berkeley.edu)... 128.32.189.73
# Connecting to colorization.eecs.berkeley.edu (colorization.eecs.berkeley.edu)|128.32.189.73|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 136785828 (130M)
# Saving to: ‘./checkpoints/siggraph_retrained/latest_net_G.pth’
#
# ./checkpoints/siggr 100%[===================>] 130.45M   805KB/s    in 2m 46s
#
# 2020-11-04 16:27:42 (806 KB/s) - ‘./checkpoints/siggraph_retrained/latest_net_G.pth’ saved [136785828/136785828]
#
# WARNING: timestamping does nothing in combination with -O. See the manual
# for details.
#
# --2020-11-04 16:27:42--  http://colorization.eecs.berkeley.edu/siggraph/models/caffemodel.pth
# ...

# %%
# !mkdir ./checkpoints/siggraph_class_small
# !cp ./checkpoints/siggraph_retrained/latest_net_G.pth ./checkpoints/siggraph_class_small/

# %%
# !ls ./checkpoints/siggraph_class_small
# Out:
# latest_net_G.pth

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 676 kB 971 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 200 kB 3.4 MB/s eta 0:00:01
# ...
#   Created wheel for visdom: filename=visdom-0.1.8.9-py3-none-any.whl size=655253 sha256=f70ad8fee095ffcf495fdb64a9846a8345a101d22456626029d9be409966af46
#   Stored in directory: /root/.cache/pip/wheels/2d/cd/fb/005445070865d4e45365b2946ee88085a7392370f152cf371c
# ...
#   Created wheel for torchfile: filename=torchfile-0.1.0-py3-none-any.whl size=5711 sha256=210697f22569dc9a10fece8b0e7c506a6e908b6d2512eeb50f9aec88facd18be
#   Stored in directory: /root/.cache/pip/wheels/55/79/ec/084a3a2e348d72852cc0c13c559c923c13ca54db86e699b681
# Successfully built visdom torchfile
# ...

# %%
# !bash ./scripts/train_siggraph.sh
# Out:
# ----------------- Options ---------------
#                    ab_max: 110.0
#                   ab_norm: 110.0
#                  ab_quant: 10.0
#              aspect_ratio: 1.0
#            avg_loss_alpha: 0.986
#                batch_size: 25
#                     beta1: 0.9
#           checkpoints_dir: ./checkpoints
#            classification: True                          	[default: False]
#              dataset_mode: aligned
#              display_freq: 10000
#                display_id: 1
#             display_ncols: 5
#              display_port: 8097
#            display_server: http://localhost
#           display_winsize: 256
#               epoch_count: 0
#                  fineSize: 176
#                   gpu_ids: 0                             	[default: -1]
#                      half: False
#                  how_many: 200
#                 init_type: normal
#                  input_nc: 5                             	[default: 1]
# ...

# %%
# !bash ./scripts/test_siggraph.sh
# Out:
# ----------------- Options ---------------
#                    ab_max: 110.0
#                   ab_norm: 110.0
#                  ab_quant: 10.0
#              aspect_ratio: 1.0
#            avg_loss_alpha: 0.986
#                batch_size: 25
#                     beta1: 0.9
#           checkpoints_dir: ./checkpoints
#            classification: True                          	[default: False]
#              dataset_mode: aligned
#              display_freq: 10000
#                display_id: 1
#             display_ncols: 5
#              display_port: 8097
#            display_server: http://localhost
#           display_winsize: 256
#               epoch_count: 0
#                  fineSize: 176
#                   gpu_ids: 0                             	[default: -1]
#                      half: False
#                  how_many: 50                            	[default: 200]
#                 init_type: normal
# ...
