# %%
# !python -m visdom.server
# Out:
# Checking for scripts.
# ...
# It's Alive!
# INFO:root:Application Started
# You can navigate to http://cnvrg-job-notebooksession-ozzddir9kfzcj8zq64o8-54876c4f89-dpb2x:8097
# INFO:tornado.access:200 POST /env/main (127.0.0.1) 0.54ms
# INFO:tornado.access:101 GET /vis_socket (127.0.0.1) 0.35ms
# INFO:root:Opened visdom socket from ip: 127.0.0.1
# INFO:tornado.access:200 POST /env/main (127.0.0.1) 0.75ms
# INFO:tornado.access:101 GET /vis_socket (127.0.0.1) 0.49ms
# INFO:root:Opened visdom socket from ip: 127.0.0.1
# INFO:tornado.access:200 POST /env/main (127.0.0.1) 0.45ms
# INFO:tornado.access:101 GET /vis_socket (127.0.0.1) 0.35ms
# INFO:root:Opened visdom socket from ip: 127.0.0.1
# INFO:tornado.access:200 POST /events (127.0.0.1) 0.96ms
# INFO:tornado.access:200 POST /events (127.0.0.1) 1.03ms
# INFO:tornado.access:200 POST /events (127.0.0.1) 0.57ms
# INFO:tornado.access:200 POST /events (127.0.0.1) 0.51ms
# INFO:tornado.access:200 POST /events (127.0.0.1) 0.58ms
# ...
